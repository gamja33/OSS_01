# %%
# 본인의 이름, 학번을 작성하여 실행하세요.
print("김태진")
print("20221160")
# Out:
# 김태진
# 20221160

# %% [markdown]
# ## 이후 강의 PDF 예제 내용을 작성하여 실행하세요.

# %%
a = [1,2,3]
b = a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
class Gizmo:
  def __init__(self):
    print("Gizmo id: %d" %id(self))

  x = Gizmo()
# Out:
# Gizmo id: 133299698583360

# %%
y = Gizmo() * 10
# Out:
# Gizmo id: 133299698381072
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2818280385.py in <cell line: 0>()
# ----> 1 y = Gizmo() * 10
#
# TypeError: unsupported operand type(s) for *: 'Gizmo' and 'int'

# %%
dir()
# Out:
# ['Gizmo',
#  'In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'b',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
charles = {'name': 'Charlse L. Dodgson', 'born': 1832}
lewis = charles

# %%
lewis is charles
# Out:
# True

# %%
id(charles), id(lewis)
# Out:
# (133299681088384, 133299681088384)

# %%
lewis['balance'] = 950
charles
# Out:
# {'name': 'Charlse L. Dodgson', 'born': 1832, 'balance': 950}

# %%
alex = {'name': 'Charles L. Dogson', 'born': 1832, 'balance': 950}
alex == charles
# Out:
# False

# %%
t1 = (1,2,[30,40])
t2 = (1,2,[30,40])
t1 == t1, t1 is t2
# Out:
# (True, False)

# %%
id(t1[-1])
# Out:
# 133299680008896

# %%
t1[-1].append(99)
t1, id(t1[-1])
# Out:
# ((1, 2, [30, 40, 99]), 133299680008896)

# %%
t1 == t2
# Out:
# False

# %%
class Bus:
  def __init__(self, passengers=None):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = list(passengers)

  def pick(self, name):
    self.passengers.append (name)

  def drop(self, name):
    self.passengers. remove (name)

# %%
import copy
bus1 = Bus( ['Alice', 'Bill', 'Claire', 'David'] )
bus2 = copy.copy(bus1)
bus3 = copy.deepcopy(bus1)
id(bus1), id(bus2), id(bus3)
# Out:
# (133299692958496, 133299964224400, 133299692950240)

# %%
bus1.drop('Bill')
bus1.passengers, bus2.passengers, bus3.passengers
# Out:
# (['Alice', 'Claire', 'David'],
#  ['Alice', 'Claire', 'David'],
#  ['Alice', 'Bill', 'Claire', 'David'])

# %%
id(bus1.passengers), id(bus2.passengers), id(bus3.passengers)
# Out:
# (133299679036800, 133299679036800, 133299680014848)

# %%
a = [10, 20]
b = [a, 30]
a.append(b)
a
# Out:
# [10, 20, [[...], 30]]

# %%
c = copy.deepcopy(a)
c
# Out:
# [10, 20, [[...], 30]]

# %%
def f(a,b):
  a+=b
  return a

x = 1
y = 2
f(x,y), (x,y)
# Out:
# (3, (1, 2))

# %%
a = [1,2]
b = [3,4]
f(a,b), (a,b)
# Out:
# ([1, 2, 3, 4], ([1, 2, 3, 4], [3, 4]))

# %%
t = (10,20)
u = (30,40)
f(t,u), (t,u)
# Out:
# ((10, 20, 30, 40), ((10, 20), (30, 40)))

# %%
class HauntedBus:
  def __init__(self, passengers=[]):
    self.passengers = passengers

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers. remove (name)

# %%
bus1 = HauntedBus(['Alice', 'Bill'])
bus1.passengers
# Out:
# ['Alice', 'Bill']

# %%
bus1.pick('Charlie')
bus1.drop('Alice')
bus1.passengers
# Out:
# ['Bill', 'Charlie']

# %%
bus2 = HauntedBus()
bus2.pick('Carrie')
bus2.passengers
# Out:
# ['Carrie']

# %%
bus3 = HauntedBus()
bus3.passengers
# Out:
# ['Carrie']

# %%
bus3.pick('Dave')
bus2.passengers
# Out:
# ['Carrie', 'Dave']

# %%
bus2.passengers is bus3.passengers
# Out:
# True

# %%
bus1.passengers
# Out:
# ['Bill', 'Charlie']

# %%
class TwilightBus:
  def __init__(self, passengers=None):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = passengers

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers.remove(name)

# %%
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Maya', 'Diana']

# %%
class TwilightBus:
  def __init__(self, passengers=None):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = list(passengers)

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers.remove(name)

# %%
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']

# %%
import weakref
s1 = {1,2,3}
s2 = s1
def bye():
  print('Gone with the wind...')

ender = weakref.finalize(s1, bye)
ender.alive
# Out:
# True

# %%
del s1
ender.alive
# Out:
# True

# %%
s2 = 'spam'
# Out:
# Gone with the wind...

# %%
ender.alive
# Out:
# False
